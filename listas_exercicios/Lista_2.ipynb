# %% [markdown]
# # Exercícios - Probabilidade

# %% [markdown]
# ### Questão 1

# %% [markdown]
# Um teste para COVID-19 possui uma taxa de 5% de falso positivo e 1% de falso negativo, ou seja, em 5% dos não-infectados acusa como infectados, e em 1% dos infectados acusa como não infectados. Sabendo que atualmente 1% da população está infectada, calcule a probabilidade de um paciente cujo teste apontou positivo estar realmente infectado.

# %%
# probabilidade de occorrer A (estar realmente infectado), dado que B ocorreu (testar positivo no teste)
P(A|B)

# FP: probabilidade de teste FALSO POSITIVO; FN: probabilidade de teste FALSO NEGATIVO
P(B) = P(FP ∪ FN) 
P(FP) = 5% = 5/100 = 1/20
P(FN) = 1% = 1/100

# Logo:
P(B) = P(FP ∪ FN) = 1/20 


P(A ∪ B)

# ?????????????????????????????????????????

# %% [markdown]
# ### Questão 2

# %% [markdown]
# A probabilidade de dado honesto é conhecido e igual a $1/6$, mas quando vamos testar isso com um dado físico, não necessariamente vai cair uma vez cada face do dado (se eu lançar ele 6 vezes). A ideia é que conforme fazermos vários testes a tendência é que a probabilidade de cada face irá convergir pro valor esperado.
#
# Vamos testar este conceito utilizando da programação seguintes os itens abaixo:]
#
# __A)__ Desenvolva uma função que receba um valor n, onde n é a quantidade de elementos e o objetivo da função é retorna uma _Series_ com n elementos sendo esses elementos números variando de 1 e 6;

# %%
import pandas as pd
import numpy as np
def series_n(n):
  amostra = np.random.randint(1, 7, n) # cria uma amostra com n valores que variam entre 1 (inclusivo) e 6 (7 é exclusivo)
  elementos = pd.Series(amostra) # transforma a variável amostra em uma Series do Pandas
  return elementos

# %% [markdown]
# __B)__ Teste a função para n igual a 10, 100, 1.000, 10.000 e 100.000 casos e para cada um deles calcule a proporção de vezes que aparece cada número;
#
# __DIca.:__ utilize a função do _Pandas_ `.value_counts`

# %%
# n = 10
n = 10
print(f'Para n = {n}: \n {series_n(n).value_counts(normalize = True).apply(lambda x: round(x * 100, 2))} \n')

# n = 100
n = 100
print(f'Para n = {n}: \n {series_n(n).value_counts(normalize = True).apply(lambda x: round(x * 100, 2))} \n')

# n = 1000
n = 1000
print(f'Para n = {n}: \n {series_n(n).value_counts(normalize = True).apply(lambda x: round(x * 100, 2))} \n')

# n = 10000
n = 10000
print(f'Para n = {n}: \n {series_n(n).value_counts(normalize = True).apply(lambda x: round(x * 100, 2))} \n')

# n = 100000
n = 100000
print(f'Para n = {n}: \n {series_n(n).value_counts(normalize = True).apply(lambda x: round(x * 100, 2))} \n')
# Out:
# Para n = 10:
#  2    30.0
# 6    30.0
# 5    20.0
# 3    20.0
# dtype: float64
#
# Para n = 100:
#  2    23.0
# 3    22.0
# 4    18.0
# 6    16.0
# 1    12.0
# 5     9.0
# dtype: float64
#
# Para n = 1000:
#  3    18.2
# 6    17.8
# 4    17.8
# 2    16.3
# 1    15.2
# 5    14.7
# dtype: float64
#
# Para n = 10000:
#  6    16.95
# 5    16.85
# 2    16.81
# 1    16.55
# 4    16.53
# 3    16.31
# dtype: float64
#
# Para n = 100000:
#  3    16.79
# 6    16.74
# 2    16.72
# 4    16.65
# 5    16.62
# 1    16.49
# dtype: float64

# %% [markdown]
# __C)__ O que podermos dizer sobre a afirmação do enunciado, a tendência é que as probabilidades irâo convergir para $1/6$?

# %%
'''
Sim, a tendência é de que a probabilidade de cada uma das faces do dado (neste caso, os número de 1 a 6) convirja para 1/6 = 16,66%, como é possível ser visto com o aumento do
número 'n' em cada um dos testes feitos na alternativa B acima.
'''

# %% [markdown]
# ### Questão 3

# %% [markdown]
# Na casa de Luiza e Rafael tem um pote de balas de diferentes cores. Certo dia a mamãe deles contou quantas balas tinha de cada uma das cores:
#
# - 14 balas azuis;
# - 22 balas vermelhas;
# - 17 balas amarelas.
#
# A mamãe deles deixou que cada um pegasse 3 balas começando pela Luiza e depois o Rafael. Dado isso resolva os item abaixo:
#
# __A)__ Qual a probabilidade da Luiza pegar uma bala de cada na ordem da contagem e o Rafael pegar 2 azuis e uma vermelha, dado que é um evento sem reposição?

# %%
# Probabilidade de A acontecer, dado que B ocorre. Neste caso, qual a probabilidade do Rafael (A) pegar 2 azuis e 1 vermelha, dado que a Luiza(A) pegou uma de cada?
# A probabilidade da Luiza pegar uma bala de cada cor, na sequência, é:

P(A) = 14/53 # Luiza tirar a bala azul
P(B) = 22/52 = 11/26 # Luiza tirar a bala vermelha
P(C) = 17/51 # Luiza tirar a bala amarela

# Logo:
P(Luiza) = 14/53 * 11/26 * 17/51 = 0.03725 = 3,7252%

# A probabilidade do Rafael pegar duas balas azuis e uma vermelha, na sequência, é:

P(D) = 13/50 # Rafael tirar a bala azul
P(E) = 12/49 # Rafael tirar outra bala azul
P(F) = 21/48 = 7/16 # Rafael tirar a bala vermelha

# Logo:
P(Rafael) = 13/50 * 12/49 * 7/16 = 0.02786 = 2.7857%

# %% [markdown]
# __B)__ Luiza decidiu ficar só com a bala amarela e devolveu as demais para o pote antes que o Rafael pegasse suas balas. Como que ficaria a probabilidade para o Rafael agora?

# %%
# A probabilidade da Luiza pegar somente a bala amarela é:

P(A) = 17/53 # Luiza tirar a bala amarela

# Logo:
P(Luiza) = 17/53 = 0.3208 = 32.0755%

# A probabilidade do Rafael pegar duas balas azuis e uma vermelha, na sequência, é:

P(B) = 14/52 = 7/26 # Rafael tirar a bala azul
P(C) = 13/51 # Rafael tirar outra bala azul
P(D) = 22/50 = 11/25 # Rafael tirar a bala vermelha

# Logo:
P(Rafael) = 7/26 * 13/51 * 11/25 = 0.0302 = 3.0196%

# %% [markdown]
# ### Questão 4

# %% [markdown]
# Um programa de computador gera uma pontuação aleatória para cada usuário, sendo que:
#
# - Em 1/2 dos casos, gera 0.5;
# - Em 1/4 dos casos, gera 0.25;
# - Em 1/8 dos casos, gera 0.125.
#
# E essa lógica segue assim por diante. Resolva os itens a seguir:
#
# __A)__ Calcule o __valor esperado__ utilizando apenas os 3 primeiros casos;

# %%
# Pela fórmula:
E[X] = ∑ x * P(X=x)

# Logo:
E[X] = (0.5 * 1/2) + (0.25 * 1/4) + (0.125 * 1/8) = 0.32815

# %% [markdown]
# __B)__ Faça um _loop_ para calcular o __valor esperado__ para 100 casos e avalie se só com os 3 primeiros casos temos uma boa aproximação ou não.

# %%
def calc_valor_esperado(y):
  soma = 0
  x = 0.5
  for i in range(y):
    soma = soma + (x * x)
    x = x / 2
  return soma

# %%
calc_valor_esperado(100)
# Out:
# 0.3333333333333333

# %%
'''
Como o valor esperado, E[X], para os 3 primeiros casos foi igual a 0.32815 e o valor esperado para os 100 primeiros casos foi igual a 0.33333, então podemos
dizer que os três primeiros valores são uma boa aproximação para o valor esperado, pois representam 0.984375 = 98.4375% do valor esperado.
'''

# %% [markdown]
# ### Questão 5

# %% [markdown]
# Em um programa de auditório, havia 3 portas (A, B, C), dentro da qual uma continha um prêmio. O participante escolheu a porta A e antes de abrir a porta o apresentador abriu a porta C, na qual não havia nada. O participante aumentará a probabilidade de acertar a porta caso mude a escolha dele da porta A para a B?
